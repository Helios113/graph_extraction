# %%
import onnx

# Load the ONNX model
model = onnx.load("model.onnx")
graph = model.graph

# 1. Graph Inputs
inputs = [inp.name for inp in graph.input]

# 2. Graph Outputs
outputs = [out.name for out in graph.output]

# 3. Model Weights/Parameters (Initializers)
initializers = [init.name for init in graph.initializer]

# 4. Computation Nodes (Operators)
nodes = graph.node  # List of NodeProto objects

# 5. Intermediate Tensor Value Infos (if shape inference was run)
value_info = [vi.name for vi in graph.value_info]
